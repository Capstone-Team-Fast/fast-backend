# %%
import sys, os

# %%
working_dir = os.path.abspath(os.path.join('..'))
parent = os.path.dirname(working_dir)

# %%
if parent not in sys.path:
    sys.path.append(parent)

# %%
for s in ["backend", "routing", "backend\models"]:
    p = os.path.join(parent, s)
    if p not in sys.path:
        sys.path.append(p)

# %%
from neomodel import config, db

from backend import settings
from routing.models.availability import Availability
from routing.models.driver import Driver
from routing.models.location import Location
from routing.models.language import Language
# Out:
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\routing\tests
# C:\ProgramData\Anaconda3\python38.zip
# C:\ProgramData\Anaconda3\DLLs
# C:\ProgramData\Anaconda3\lib
# C:\ProgramData\Anaconda3
#
# C:\Users\WINDS\AppData\Roaming\Python\Python38\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages\win32
# C:\ProgramData\Anaconda3\lib\site-packages\win32\lib
# C:\ProgramData\Anaconda3\lib\site-packages\Pythonwin
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions
# C:\Users\WINDS\.ipython
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\backend
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\routing
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\backend\models
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\routing\tests
# C:\ProgramData\Anaconda3\python38.zip
# C:\ProgramData\Anaconda3\DLLs
# C:\ProgramData\Anaconda3\lib
# C:\ProgramData\Anaconda3
#
# C:\Users\WINDS\AppData\Roaming\Python\Python38\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages
# C:\ProgramData\Anaconda3\lib\site-packages\win32
# C:\ProgramData\Anaconda3\lib\site-packages\win32\lib
# C:\ProgramData\Anaconda3\lib\site-packages\Pythonwin
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\extensions
# C:\Users\WINDS\.ipython
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\backend
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\routing
# C:\Users\WINDS\OneDrive - University of Nebraska at Omaha\Capstone Project\fast-backend\backend\models

# %%
def add_driver(db_connection):
    with db_connection.transaction:
        drivers = Driver.create(
            {'first_name': 'John', 'last_name': 'Doe', 'employee_status': 'P'},
            {'first_name': 'Jane', 'last_name': 'Doe', 'employee_status': 'V'},
            {'first_name': 'Alexander', 'last_name': 'Ortega', 'employee_status': 'V'},
            {'first_name': 'Rahul', 'last_name': 'Martinez', 'employee_status': 'V'},
            {'first_name': 'Martin', 'last_name': 'Cordova', 'employee_status': 'P'},
            {'first_name': 'Mark', 'last_name': 'Fernandez', 'employee_status': 'V'},
            {'first_name': 'Shaine', 'last_name': 'Alenin', 'employee_status': 'V'},
            {'first_name': 'Thurston', 'last_name': 'Wayon', 'employee_status': 'V'},
            {'first_name': 'Darnall', 'last_name': 'Frear', 'employee_status': 'P'},
            {'first_name': 'Ronalda', 'last_name': 'Carlyon', 'employee_status': 'V'},
            {'first_name': 'Blakeley', 'last_name': 'Gunby', 'employee_status': 'P'},
            {'first_name': 'Yorke', 'last_name': 'Hartington', 'employee_status': 'V'},
            {'first_name': 'Ryann', 'last_name': 'Britcher', 'employee_status': 'V'},
            {'first_name': 'Adamo', 'last_name': 'Paxton', 'employee_status': 'P'},
            {'first_name': 'Kristoffer', 'last_name': 'Pagan', 'employee_status': 'P'},
            {'first_name': 'Trevor', 'last_name': 'Ollin', 'employee_status': 'V'}
        )
    return drivers

# %%
def add_locations(db_connection):
    with db_connection.transaction:
        locations = Location.create(
            {'address': '5545 Center St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68106, 'is_center': True},
            {'address': '9029 Burt St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68114},
            {'address': '9110 Maplewood Blvd', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68134},
            {'address': '9715 Ohern Plz', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68127},
            {'address': '8170 Browne St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68134},
            {'address': '6705 S 85th St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68127},
            {'address': '6795 Emmet St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68104},
            {'address': '7115 N 50th Ave', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68152},
            {'address': '7205 N 73rd Plaza Cir', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68122},
            {'address': '7350 Graceland Dr', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68134},
            {'address': '4550 Walnut St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68106},
            {'address': '15423 Lloyd St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68144},
            {'address': '12205 Farnam St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68154},
            {'address': '2117 S 38th St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68105},
            {'address': '1019 S 106th Plz', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68114},
            {'address': '11679 Fowler Ave', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68164},
            {'address': '7909 Grover St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68124},
            {'address': '530 Loveland Dr', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68114},
            {'address': '1875 S 75th St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68124},
            {'address': '14455 Harrison St', 'city': 'Omaha', 'state': 'NE', 'zipcode': 68138}
        )
    return locations

# %%
def add_availability(db_connection):
    with db_connection.transaction:
        days = Availability.create(
            {'day': 'Monday'},
            {'day': 'Tuesday'},
            {'day': 'Wednesday'},
            {'day': 'Thursday'},
            {'day': 'Friday'},
            {'day': 'Saturday'},
            {'day': 'Sunday'},
        )
    return days

# %%
def add_languages(db_connection):
    with db_connection.transaction:
        languages = Language.create(
            {'language': 'English'},
            {'language': 'Spanish'},
            {'language': 'Arabic'},
            {'language': 'Burmese'},
            {'language': 'Somali'},
            {'language': 'Sudanese'},
        )
    return languages

# %%
config.DATABASE_URL = settings.NEOMODEL_NEO4J_BOLT_URL
db.set_connection(url=config.DATABASE_URL)

print(db.url)

# print('Adding drivers to db')
# all_drivers = add_driver(db_connection=db)

# print('Adding locations to db')
# all_locations = add_locations(db_connection=db)

# print('Adding languages to db')
# all_languages = add_languages(db_connection=db)

# print('Adding availability to db')
# all_days = add_availability(db_connection=db)
# Out:
# bolt://neo4j:password@localhost:7687

# %%
all_days = Availability.nodes.all()
all_locations = Location.nodes.all()
all_languages = Language.nodes.all()

# %%
depot = Location.nodes.get(is_center= True)
depot
# Out:
# <Location: 5545 Center St, Omaha, NE 68106>

# %%
all_drivers = Driver.nodes.all()

# %%
# # Driver 0
# all_drivers[0].is_available_on.connect(all_days[0])
# all_drivers[0].is_available_on.connect(all_days[1])
# all_drivers[0].is_available_on.connect(all_days[2])
# all_drivers[0].is_available_on.connect(all_days[4])
# all_drivers[0].speaks.connect(all_languages[0])
# # all_drivers[0].speaks.connect(all_languages[1])
# all_drivers[0].speaks.connect(all_languages[2])

# # Driver 1
# all_drivers[1].is_available_on.connect(all_days[0])
# all_drivers[1].is_available_on.connect(all_days[1])
# all_drivers[1].is_available_on.connect(all_days[2])
# all_drivers[1].is_available_on.connect(all_days[4])
# all_drivers[1].speaks.connect(all_languages[1])
# all_drivers[1].speaks.connect(all_languages[2])
# all_drivers[1].speaks.connect(all_languages[3])

# # Driver 2
# all_drivers[2].is_available_on.connect(all_days[0])
# all_drivers[2].is_available_on.connect(all_days[1])
# all_drivers[2].is_available_on.connect(all_days[2])
# all_drivers[2].is_available_on.connect(all_days[3])
# all_drivers[2].is_available_on.connect(all_days[5])
# all_drivers[2].speaks.connect(all_languages[2])
# all_drivers[2].speaks.connect(all_languages[3])
# all_drivers[2].speaks.connect(all_languages[4])
# all_drivers[2].speaks.connect(all_languages[5])

# # Driver 3
# all_drivers[3].is_available_on.connect(all_days[0])
# all_drivers[3].is_available_on.connect(all_days[1])
# all_drivers[3].is_available_on.connect(all_days[2])
# all_drivers[3].is_available_on.connect(all_days[3])
# all_drivers[3].is_available_on.connect(all_days[4])
# all_drivers[3].is_available_on.connect(all_days[5])
# all_drivers[3].is_available_on.connect(all_days[6])
# all_drivers[3].speaks.connect(all_languages[1])
# all_drivers[3].speaks.connect(all_languages[2])
# all_drivers[3].speaks.connect(all_languages[5])

# %%
# all_locations[0].neighbor.connect(all_locations[1], {'distance': 43.29, 'duration': 45})
# all_locations[0].neighbor.connect(all_locations[2], {'distance': 33.29, 'duration': 35})
# all_locations[0].neighbor.connect(all_locations[3], {'distance': 23.24, 'duration': 25})
# all_locations[0].neighbor.connect(all_locations[4], {'distance': 53.25, 'duration': 55})
# all_locations[0].neighbor.connect(all_locations[5], {'distance': 3.25, 'duration': 4})
# all_locations[1].neighbor.connect(all_locations[2], {'distance': 23.25, 'duration': 25})
# all_locations[1].neighbor.connect(all_locations[3], {'distance': 23.4, 'duration': 25})
# all_locations[2].neighbor.connect(all_locations[4], {'distance': 22.7, 'duration': 25})
# all_locations[4].neighbor.connect(all_locations[5], {'distance': 13.2, 'duration': 15})

# %%
# Relationships are symmetric
print('Distance from 0 to 1', all_locations[0].neighbor.relationship(all_locations[1]).distance)
print('Distance from 1 to 0', all_locations[1].neighbor.relationship(all_locations[0]).distance)
# Out:
# Distance from 0 to 1 8.281
# Distance from 1 to 0 8.281

# %%
all_locations[1].neighbor.relationship(all_locations[10]).distance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-4736b2747ae9> in <module>
# ----> 1 all_locations[1].neighbor.relationship(all_locations[10]).distance
#
# AttributeError: 'NoneType' object has no attribute 'distance'

# %% [markdown]
# ### Test LocationManager

# %%
from routing.managers import LocationManager

# %%
location_manager = LocationManager(db, depot=depot)

# %%
location_manager.size()

# %%
if None and None:
    print('None')

# %%
location_manager.remove(all_locations[1])

# %%
location_manager.get_locations()

# %%
location_manager = LocationManager(db, depot=depot)
location_manager.add(all_locations[0])
print(location_manager.size() == 1)
test_set = set()
test_set.add(all_locations[0])
print(location_manager.get_locations() == list(test_set))
# location_manager.delete(all_locations[1]) # Raise KeyError
location_manager.remove(all_locations[0])
print(location_manager.size() == 0)
location_manager.add_collection(all_locations[:5])
print(location_manager.size() == 5)

# %%
# Get distance is symmetric
print(location_manager.get_distance(all_locations[0], all_locations[1]) == location_manager.get_distance(all_locations[1], all_locations[0]))

# Get duration is symmetric
print(location_manager.get_duration(all_locations[0], all_locations[1]) == location_manager.get_duration(all_locations[1], all_locations[0]))

# Get distance savings
print(location_manager.get_distance_savings(all_locations[1], all_locations[2]))
print(location_manager.get_distance_savings(all_locations[2], all_locations[1]))

# Get distance savings is symmetric
print(location_manager.get_distance_savings(all_locations[1], all_locations[2]) == location_manager.get_distance_savings(all_locations[2], all_locations[1]))

# Get duration savings
print(location_manager.get_duration_savings(all_locations[1], all_locations[2]))
print(location_manager.get_duration_savings(all_locations[2], all_locations[1]))

# Get duration savings is symmetric
print(location_manager.get_duration_savings(all_locations[1], all_locations[2]) == location_manager.get_duration_savings(all_locations[2], all_locations[1]))

# %%
for l in location_manager.get_locations():
    print(l.address, l.is_center, l.is_assigned, l.latitude, l.longitude)

# %%
location_manager.remove(1)

# %% [markdown]
# ### Test SavingsManager

# %%
from routing.managers import SavingsManager

# %%
savings_manager = SavingsManager(db_connection=db, depot=depot, locations=all_locations[1:6])

# %%
savings_manager.depot

# %%
while True:
    try:
        savings, pair = next(savings_manager)
        print(savings, pair.get_pair())
    except IndexError:
        break

# %% [markdown]
# ### Test BingGeocodeService

# %%
from routing.services import BingGeocodeService

# %%
text = BingGeocodeService.get_geocode(depot)

# %%
text

# %% [markdown]
# ### Test BingMatrixService

# %%
from routing.services import BingMatrixService

# %%
m = BingMatrixService.build_matrices(start=depot, end=all_locations[:40])

# %%
for l in all_locations[:10]:
    print(l)

# %%
for l in all_locations[:10]:
    print(depot.neighbor.relationship(l).distance)

# %%
m.json()

# %%
d.keys()

# %%
d = m.json()
d = d['resourceSets'][0]
d.keys()
d = d['resources'][0]
d.keys()
dest = d['destinations']
orig = d['origins']
result = d['results']

# %%
dest

# %%
orig

# %%
result

# %%
for d in result:
    destinationIndex = d['destinationIndex']
    originIndex = d['originIndex']
    destination = dest[destinationIndex]
    origin = orig[originIndex]
    print(destination, origin)

# %%
Location.nodes.get(latitude=41.238347, longitude=-95.998385)

# %% [markdown]
# ### Test Route

# %%
from routing.models.route import Route
from itertools import combinations
from routing.models.location import Pair
from random import randint, shuffle

# %%
r = Route()
r.departure = depot
r.departure

# %%
drivers = all_drivers[:5]
for driver in drivers:
    print(driver)

# %%
locs = all_locations[1:6]
pairs = []
for p in combinations(locs, 2):
    pairs.append(Pair(p[0], p[1]))
    
# Shuffle pairs
shuffle(pairs)

# %%
r.is_open
print(r.get_created_on())
print(r.get_total_demand() == 0)
print(r.get_total_distance() == 0)
print(r.get_total_duration() == 0)
print(r.last_location() == None)

# %% [markdown]
# #### Test add

# %%
for l in locs:
    if l != depot:
        l.demand = randint(1, 10)
    else:
        l.demand = None
    print(l, l.demand)
    l.is_assigned = False

# %%
r.locations_dict

# %%
r.locations_dict

# %%
r.locations_queue

# %%
r.locations_queue

# %%
last_inserted = r.locations_queue.pop()
last_inserted

# %%
print(hex(id(last_inserted)))
print(r.locations_dict[hex(id(last_inserted))])
print(r.locations_dict[hex(id(last_inserted))].next == None)
r.locations_dict[hex(id(last_inserted))].previous.next = r.locations_dict[hex(id(last_inserted))].next

# %%
print(r.locations_dict['0x2411ba4ed00'].next)

# %%
r.last_location()

# %%
n = r.departure
while n is not None:
    if n.next is None:
        print(n)
    else:
        print(n, "\033[1m --> \033[0m", end="")
    n = n.next

# %%
n = r.last_location()
while n is not None:
    if n.previous is None:
        print(n)
    else:
        print(n, "\033[1m --> \033[0m", end="")
    n = n.previous

# %%
r.undo()

# %%
while True:
    try:
        savings, p = next(savings_manager)
        print(f"Processing pair ({p.first()}, {p.last()})")
        for l in p.get_pair():
            print(f"\tProcessing location {l}")
            r.add(l, p)
    except IndexError:
        break

# %%
r

# %%
next(savings_manager)

# %%
savings

# %%
r.last_location()

# %%
r.get_total_demand()

# %%
r.locations_dict

# %%
r.locations_queue

# %%
hex(id(r.previous))

# %%
r.last_location()

# %%
hex(id(r.last_location()))

# %%
r.undo()

# %%
hex(id(r.locations_dict['0x2411ba3fb80'].next.next.next))

# %%
hex(id(r.locations_dict['0x2411ba4e4f0'].previous.previous.previous.previous))

# %%
r.locations_dict

# %%
for i in range(0, 15, 10):
    if i + 10 < 15:
        print(f'From i = {i} to j = {i + 10}')
    else:
        print(f'From i = {i} to end')

# %% [markdown]
# ### Test RouteManager

# %%
from routing.managers import RouteManager
from random import randint
from datetime import datetime, timedelta

# %%
# Set driver's capacity
for driver in all_drivers:
    driver.capacity = randint(15, 20)

# Set driver's start and end time
for driver in all_drivers:
    driver.start_time = datetime(year=2021, month=10, day=31, hour=randint(9, 12), minute=0)
    driver.end_time = datetime(year=2021, month=10, day=31, hour=randint(12, 13), minute=0)

# %%
route_manager = RouteManager(db_connection=db, depot=depot, drivers=all_drivers[:5], locations=all_locations[1:10])
# Out:
# Requesting matrix between '5545 Center St, Omaha, NE 68106' and '[]'
#
# Added new location 5545 Center St, Omaha, NE 68106
# LocationManager State {<Location: 5545 Center St, Omaha, NE 68106>}
#
#
# Requesting matrix between '9029 Burt St, Omaha, NE 68114' and '[<Location: 5545 Center St, Omaha, NE 68106>]'
#
# Destinations: []
#
# Added new location 9029 Burt St, Omaha, NE 68114
# LocationManager State {<Location: 5545 Center St, Omaha, NE 68106>, <Location: 9029 Burt St, Omaha, NE 68114>}
#
#
# Requesting matrix between '9110 Maplewood Blvd, Omaha, NE 68134' and '[<Location: 5545 Center St, Omaha, NE 68106>, <Location: 9029 Burt St, Omaha, NE 68114>]'
#
# Destinations: []
#
# Added new location 9110 Maplewood Blvd, Omaha, NE 68134
# LocationManager State {<Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9029 Burt St, Omaha, NE 68114>}
#
#
# Requesting matrix between '9715 Ohern Plz, Omaha, NE 68127' and '[<Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9029 Burt St, Omaha, NE 68114>]'
#
# Destinations: []
#
# Added new location 9715 Ohern Plz, Omaha, NE 68127
# LocationManager State {<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9029 Burt St, Omaha, NE 68114>}
#
#
# Requesting matrix between '8170 Browne St, Omaha, NE 68134' and '[<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9029 Burt St, Omaha, NE 68114>]'
#
# Destinations: []
#
# Added new location 8170 Browne St, Omaha, NE 68134
# LocationManager State {<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>}
#
#
# Requesting matrix between '6705 S 85th St, Omaha, NE 68127' and '[<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>]'
#
# Destinations: []
#
# Added new location 6705 S 85th St, Omaha, NE 68127
# LocationManager State {<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 6705 S 85th St, Omaha, NE 68127>}
#
#
# Requesting matrix between '6795 Emmet St, Omaha, NE 68104' and '[<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 6705 S 85th St, Omaha, NE 68127>]'
#
# Destinations: []
#
# Added new location 6795 Emmet St, Omaha, NE 68104
# LocationManager State {<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 6795 Emmet St, Omaha, NE 68104>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 6705 S 85th St, Omaha, NE 68127>}
#
#
# Requesting matrix between '7115 N 50th Ave, Omaha, NE 68152' and '[<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 6795 Emmet St, Omaha, NE 68104>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 6705 S 85th St, Omaha, NE 68127>]'
#
# Destinations: []
#
# Added new location 7115 N 50th Ave, Omaha, NE 68152
# LocationManager State {<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 6795 Emmet St, Omaha, NE 68104>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 7115 N 50th Ave, Omaha, NE 68152>, <Location: 6705 S 85th St, Omaha, NE 68127>}
#
#
# Requesting matrix between '7205 N 73rd Plaza Cir, Omaha, NE 68122' and '[<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 6795 Emmet St, Omaha, NE 68104>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 7115 N 50th Ave, Omaha, NE 68152>, <Location: 6705 S 85th St, Omaha, NE 68127>]'
#
# Destinations: []
#
# Added new location 7205 N 73rd Plaza Cir, Omaha, NE 68122
# LocationManager State {<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 6795 Emmet St, Omaha, NE 68104>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 7205 N 73rd Plaza Cir, Omaha, NE 68122>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 7115 N 50th Ave, Omaha, NE 68152>, <Location: 6705 S 85th St, Omaha, NE 68127>}
#
#
# Requesting matrix between '7350 Graceland Dr, Omaha, NE 68134' and '[<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 6795 Emmet St, Omaha, NE 68104>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 7205 N 73rd Plaza Cir, Omaha, NE 68122>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 7115 N 50th Ave, Omaha, NE 68152>, <Location: 6705 S 85th St, Omaha, NE 68127>]'
#
# Destinations: []
#
# Added new location 7350 Graceland Dr, Omaha, NE 68134
# LocationManager State {<Location: 9715 Ohern Plz, Omaha, NE 68127>, <Location: 5545 Center St, Omaha, NE 68106>, <Location: 6795 Emmet St, Omaha, NE 68104>, <Location: 9110 Maplewood Blvd, Omaha, NE 68134>, <Location: 7205 N 73rd Plaza Cir, Omaha, NE 68122>, <Location: 9029 Burt St, Omaha, NE 68114>, <Location: 7350 Graceland Dr, Omaha, NE 68134>, <Location: 8170 Browne St, Omaha, NE 68134>, <Location: 7115 N 50th Ave, Omaha, NE 68152>, <Location: 6705 S 85th St, Omaha, NE 68127>}

# %%
# Set locations demand
for location in route_manager.locations:
    location.demand = randint(5, 10)

# %%
for location in route_manager.locations:
    print(location, location.demand)

print()

for driver in route_manager.drivers:
    print(driver, driver.capacity, driver.start_time, driver.end_time, (driver.end_time - driver.start_time).total_seconds())
# Out:
# 9029 Burt St, Omaha, NE 68114 10
# 9110 Maplewood Blvd, Omaha, NE 68134 6
# 9715 Ohern Plz, Omaha, NE 68127 6
# 8170 Browne St, Omaha, NE 68134 10
# 6705 S 85th St, Omaha, NE 68127 5
# 6795 Emmet St, Omaha, NE 68104 5
# 7115 N 50th Ave, Omaha, NE 68152 5
# 7205 N 73rd Plaza Cir, Omaha, NE 68122 9
# 7350 Graceland Dr, Omaha, NE 68134 5
#
# Doe,John 20 2021-10-31 09:00:00 2021-10-31 13:00:00 14400.0
# Doe,Jane 17 2021-10-31 11:00:00 2021-10-31 12:00:00 3600.0
# Ortega,Alexander 20 2021-10-31 11:00:00 2021-10-31 12:00:00 3600.0
# Martinez,Rahul 18 2021-10-31 09:00:00 2021-10-31 12:00:00 10800.0
# Cordova,Martin 17 2021-10-31 10:00:00 2021-10-31 13:00:00 10800.0

# %%
route_manager.build_routes()
# Out:
#  Processing pair (7115 N 50th Ave, Omaha, NE 68152, 7205 N 73rd Plaza Cir, Omaha, NE 68122)
# 	Using  driver 'Doe,John'  Capacity: 20
# 		Processing location 7115 N 50th Ave, Omaha, NE 68152 Capacity: 5 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7115 N 50th Ave, Omaha, NE 68152
# Location 7205 N 73rd Plaza Cir, Omaha, NE 68122 is last and tail is 7115 N 50th Ave, Omaha, NE 68152
# Location 7115 N 50th Ave, Omaha, NE 68152 is exterior
# Inserting 7205 N 73rd Plaza Cir, Omaha, NE 68122 to the front
# 		Processing location 7205 N 73rd Plaza Cir, Omaha, NE 68122 Capacity: 9 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122
#
#  Processing pair (8170 Browne St, Omaha, NE 68134, 7115 N 50th Ave, Omaha, NE 68152)
# 	Using  driver 'Doe,John'  Capacity: 20
# Location 8170 Browne St, Omaha, NE 68134 is first and head is 7115 N 50th Ave, Omaha, NE 68152
# Location 7115 N 50th Ave, Omaha, NE 68152 is exterior
# Inserting 8170 Browne St, Omaha, NE 68134 to the back
# 		Processing location 8170 Browne St, Omaha, NE 68134 Capacity: 10 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 8170 Browne St, Omaha, NE 68134 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122
#
# Route is overcapacity.
#
# Undid insertion of 8170 Browne St, Omaha, NE 68134
# Closing route.
#
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 		Processing location 8170 Browne St, Omaha, NE 68134 Capacity: 10 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 8170 Browne St, Omaha, NE 68134 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122 --> 5545 Center St, Omaha, NE 68106
# 7115 N 50th Ave, Omaha, NE 68152 is already assigned.
#
#  Processing pair (7115 N 50th Ave, Omaha, NE 68152, 7350 Graceland Dr, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 7115 N 50th Ave, Omaha, NE 68152 is already assigned.
# Location 7350 Graceland Dr, Omaha, NE 68134 is last and tail is 8170 Browne St, Omaha, NE 68134
# 		Processing location 7350 Graceland Dr, Omaha, NE 68134 Capacity: 5 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 8170 Browne St, Omaha, NE 68134 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122 --> 5545 Center St, Omaha, NE 68106
#
#  Processing pair (9110 Maplewood Blvd, Omaha, NE 68134, 7115 N 50th Ave, Omaha, NE 68152)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# Location 9110 Maplewood Blvd, Omaha, NE 68134 is first and head is 8170 Browne St, Omaha, NE 68134
# 		Processing location 9110 Maplewood Blvd, Omaha, NE 68134 Capacity: 6 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 8170 Browne St, Omaha, NE 68134 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122 --> 5545 Center St, Omaha, NE 68106
# 7115 N 50th Ave, Omaha, NE 68152 is already assigned.
#
#  Processing pair (6795 Emmet St, Omaha, NE 68104, 7115 N 50th Ave, Omaha, NE 68152)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# Location 6795 Emmet St, Omaha, NE 68104 is first and head is 8170 Browne St, Omaha, NE 68134
# 		Processing location 6795 Emmet St, Omaha, NE 68104 Capacity: 5 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 8170 Browne St, Omaha, NE 68134 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122 --> 5545 Center St, Omaha, NE 68106
# 7115 N 50th Ave, Omaha, NE 68152 is already assigned.
#
#  Processing pair (8170 Browne St, Omaha, NE 68134, 7205 N 73rd Plaza Cir, Omaha, NE 68122)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 8170 Browne St, Omaha, NE 68134 is already assigned.
# 7205 N 73rd Plaza Cir, Omaha, NE 68122 is already assigned.
#
#  Processing pair (7205 N 73rd Plaza Cir, Omaha, NE 68122, 7350 Graceland Dr, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 7205 N 73rd Plaza Cir, Omaha, NE 68122 is already assigned.
# Location 7350 Graceland Dr, Omaha, NE 68134 is last and tail is 8170 Browne St, Omaha, NE 68134
# 		Processing location 7350 Graceland Dr, Omaha, NE 68134 Capacity: 5 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 8170 Browne St, Omaha, NE 68134 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122 --> 5545 Center St, Omaha, NE 68106
#
#  Processing pair (9110 Maplewood Blvd, Omaha, NE 68134, 8170 Browne St, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# Location 9110 Maplewood Blvd, Omaha, NE 68134 is first and head is 8170 Browne St, Omaha, NE 68134
# Location 8170 Browne St, Omaha, NE 68134 is exterior
# Inserting 9110 Maplewood Blvd, Omaha, NE 68134 to the back
# 		Processing location 9110 Maplewood Blvd, Omaha, NE 68134 Capacity: 6 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9110 Maplewood Blvd, Omaha, NE 68134 --> 8170 Browne St, Omaha, NE 68134 --> 7115 N 50th Ave, Omaha, NE 68152 --> 7205 N 73rd Plaza Cir, Omaha, NE 68122 --> 5545 Center St, Omaha, NE 68106
# 8170 Browne St, Omaha, NE 68134 is already assigned.
#
#  Processing pair (8170 Browne St, Omaha, NE 68134, 7350 Graceland Dr, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 8170 Browne St, Omaha, NE 68134 is already assigned.
# Location 7350 Graceland Dr, Omaha, NE 68134 is last and tail is 8170 Browne St, Omaha, NE 68134
# Location 8170 Browne St, Omaha, NE 68134 is exterior
# Inserting 7350 Graceland Dr, Omaha, NE 68134 to the front
# 		Processing location 7350 Graceland Dr, Omaha, NE 68134 Capacity: 5 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9110 Maplewood Blvd, Omaha, NE 68134 --> 8170 Browne St, Omaha, NE 68134 --> 7350 Graceland Dr, Omaha, NE 68134
#
# Route is overcapacity.
#
# Undid insertion of 7350 Graceland Dr, Omaha, NE 68134
# Closing route.
#
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 8170 Browne St, Omaha, NE 68134 is already assigned.
# 		Processing location 7350 Graceland Dr, Omaha, NE 68134 Capacity: 5 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7350 Graceland Dr, Omaha, NE 68134
#
#  Processing pair (9110 Maplewood Blvd, Omaha, NE 68134, 7205 N 73rd Plaza Cir, Omaha, NE 68122)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 9110 Maplewood Blvd, Omaha, NE 68134 is already assigned.
# 7205 N 73rd Plaza Cir, Omaha, NE 68122 is already assigned.
#
#  Processing pair (6795 Emmet St, Omaha, NE 68104, 7350 Graceland Dr, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# Location 6795 Emmet St, Omaha, NE 68104 is first and head is 7350 Graceland Dr, Omaha, NE 68134
# Location 7350 Graceland Dr, Omaha, NE 68134 is exterior
# Inserting 6795 Emmet St, Omaha, NE 68104 to the front
# 		Processing location 6795 Emmet St, Omaha, NE 68104 Capacity: 5 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104
# 7350 Graceland Dr, Omaha, NE 68134 is already assigned.
#
#  Processing pair (8170 Browne St, Omaha, NE 68134, 6795 Emmet St, Omaha, NE 68104)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 8170 Browne St, Omaha, NE 68134 is already assigned.
# 6795 Emmet St, Omaha, NE 68104 is already assigned.
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 7115 N 50th Ave, Omaha, NE 68152)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# Location 9029 Burt St, Omaha, NE 68114 is first and head is 7350 Graceland Dr, Omaha, NE 68134
# 		Processing location 9029 Burt St, Omaha, NE 68114 Capacity: 10 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104
# 7115 N 50th Ave, Omaha, NE 68152 is already assigned.
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 9110 Maplewood Blvd, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# Location 9029 Burt St, Omaha, NE 68114 is first and head is 7350 Graceland Dr, Omaha, NE 68134
# 		Processing location 9029 Burt St, Omaha, NE 68114 Capacity: 10 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104
# 9110 Maplewood Blvd, Omaha, NE 68134 is already assigned.
#
#  Processing pair (9110 Maplewood Blvd, Omaha, NE 68134, 7350 Graceland Dr, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 9110 Maplewood Blvd, Omaha, NE 68134 is already assigned.
# 7350 Graceland Dr, Omaha, NE 68134 is already assigned.
#
#  Processing pair (9110 Maplewood Blvd, Omaha, NE 68134, 6795 Emmet St, Omaha, NE 68104)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 9110 Maplewood Blvd, Omaha, NE 68134 is already assigned.
# 6795 Emmet St, Omaha, NE 68104 is already assigned.
#
#  Processing pair (9715 Ohern Plz, Omaha, NE 68127, 6705 S 85th St, Omaha, NE 68127)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# Location 9715 Ohern Plz, Omaha, NE 68127 is first and head is 7350 Graceland Dr, Omaha, NE 68134
# 		Processing location 9715 Ohern Plz, Omaha, NE 68127 Capacity: 6 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104
# Location 6705 S 85th St, Omaha, NE 68127 is last and tail is 6795 Emmet St, Omaha, NE 68104
# 		Processing location 6705 S 85th St, Omaha, NE 68127 Capacity: 5 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104
# _State.INFEASIBLE
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 8170 Browne St, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# Location 9029 Burt St, Omaha, NE 68114 is first and head is 7350 Graceland Dr, Omaha, NE 68134
# 		Processing location 9029 Burt St, Omaha, NE 68114 Capacity: 10 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104
# 8170 Browne St, Omaha, NE 68134 is already assigned.
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 7350 Graceland Dr, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# Location 9029 Burt St, Omaha, NE 68114 is first and head is 7350 Graceland Dr, Omaha, NE 68134
# Location 7350 Graceland Dr, Omaha, NE 68134 is exterior
# Inserting 9029 Burt St, Omaha, NE 68114 to the back
# 		Processing location 9029 Burt St, Omaha, NE 68114 Capacity: 10 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9029 Burt St, Omaha, NE 68114 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104
#
# Route is overcapacity.
#
# Undid insertion of 9029 Burt St, Omaha, NE 68114
# Closing route.
#
# 	Using  driver 'Doe,Jane'  Capacity: 17
# 		Processing location 9029 Burt St, Omaha, NE 68114 Capacity: 10 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9029 Burt St, Omaha, NE 68114 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104 --> 5545 Center St, Omaha, NE 68106
# 7350 Graceland Dr, Omaha, NE 68134 is already assigned.
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 7205 N 73rd Plaza Cir, Omaha, NE 68122)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# 9029 Burt St, Omaha, NE 68114 is already assigned.
# 7205 N 73rd Plaza Cir, Omaha, NE 68122 is already assigned.
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 6795 Emmet St, Omaha, NE 68104)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# 9029 Burt St, Omaha, NE 68114 is already assigned.
# 6795 Emmet St, Omaha, NE 68104 is already assigned.
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 9715 Ohern Plz, Omaha, NE 68127)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# 9029 Burt St, Omaha, NE 68114 is already assigned.
# Location 9715 Ohern Plz, Omaha, NE 68127 is last and tail is 9029 Burt St, Omaha, NE 68114
# Location 9029 Burt St, Omaha, NE 68114 is exterior
# Inserting 9715 Ohern Plz, Omaha, NE 68127 to the back
# 		Processing location 9715 Ohern Plz, Omaha, NE 68127 Capacity: 6 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9715 Ohern Plz, Omaha, NE 68127 --> 9029 Burt St, Omaha, NE 68114 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104 --> 5545 Center St, Omaha, NE 68106
#
#  Processing pair (9110 Maplewood Blvd, Omaha, NE 68134, 9715 Ohern Plz, Omaha, NE 68127)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# 9110 Maplewood Blvd, Omaha, NE 68134 is already assigned.
# 9715 Ohern Plz, Omaha, NE 68127 is already assigned.
#
#  Processing pair (6705 S 85th St, Omaha, NE 68127, 7350 Graceland Dr, Omaha, NE 68134)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# Location 6705 S 85th St, Omaha, NE 68127 is first and head is 9715 Ohern Plz, Omaha, NE 68127
# 		Processing location 6705 S 85th St, Omaha, NE 68127 Capacity: 5 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9715 Ohern Plz, Omaha, NE 68127 --> 9029 Burt St, Omaha, NE 68114 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104 --> 5545 Center St, Omaha, NE 68106
# 7350 Graceland Dr, Omaha, NE 68134 is already assigned.
#
#  Processing pair (6705 S 85th St, Omaha, NE 68127, 6795 Emmet St, Omaha, NE 68104)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# Location 6705 S 85th St, Omaha, NE 68127 is first and head is 9715 Ohern Plz, Omaha, NE 68127
# 		Processing location 6705 S 85th St, Omaha, NE 68127 Capacity: 5 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9715 Ohern Plz, Omaha, NE 68127 --> 9029 Burt St, Omaha, NE 68114 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104 --> 5545 Center St, Omaha, NE 68106
# 6795 Emmet St, Omaha, NE 68104 is already assigned.
#
#  Processing pair (6705 S 85th St, Omaha, NE 68127, 7115 N 50th Ave, Omaha, NE 68152)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# Location 6705 S 85th St, Omaha, NE 68127 is first and head is 9715 Ohern Plz, Omaha, NE 68127
# 		Processing location 6705 S 85th St, Omaha, NE 68127 Capacity: 5 Assigned: False
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9715 Ohern Plz, Omaha, NE 68127 --> 9029 Burt St, Omaha, NE 68114 --> 7350 Graceland Dr, Omaha, NE 68134 --> 6795 Emmet St, Omaha, NE 68104 --> 5545 Center St, Omaha, NE 68106
# 7115 N 50th Ave, Omaha, NE 68152 is already assigned.
#
#  Processing pair (9715 Ohern Plz, Omaha, NE 68127, 7115 N 50th Ave, Omaha, NE 68152)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# 9715 Ohern Plz, Omaha, NE 68127 is already assigned.
# 7115 N 50th Ave, Omaha, NE 68152 is already assigned.
#
#  Processing pair (9029 Burt St, Omaha, NE 68114, 6705 S 85th St, Omaha, NE 68127)
# 	Using  driver 'Doe,John'  Capacity: 20
# 	Using  driver 'Ortega,Alexander'  Capacity: 20
# 	Using  driver 'Martinez,Rahul'  Capacity: 18
# 	Using  driver 'Doe,Jane'  Capacity: 17
# 9029 Burt St, Omaha, NE 68114 is already assigned.
# Location 6705 S 85th St, Omaha, NE 68127 is last and tail is 9029 Burt St, Omaha, NE 68114
# Location 9029 Burt St, Omaha, NE 68114 is exterior
# Inserting 6705 S 85th St, Omaha, NE 68127 to the front
# 		Processing location 6705 S 85th St, Omaha, NE 68127 Capacity: 5 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 9715 Ohern Plz, Omaha, NE 68127 --> 9029 Burt St, Omaha, NE 68114 --> 6705 S 85th St, Omaha, NE 68127
#
# Route is overcapacity.
#
# Undid insertion of 6705 S 85th St, Omaha, NE 68127
# Closing route.
#
# 	Using  driver 'Cordova,Martin'  Capacity: 17
# 9029 Burt St, Omaha, NE 68114 is already assigned.
# 		Processing location 6705 S 85th St, Omaha, NE 68127 Capacity: 5 Assigned: True
# 			Locations:  5545 Center St, Omaha, NE 68106 --> 6705 S 85th St, Omaha, NE 68127
# <_State.SOLVED: 3>

# %%
for driver in route_manager.drivers_heap:
    print('\033[1m', 'Driver: ', driver, '\033[0m', '\033[1m', 'Capacity: ', '\033[0m', driver.capacity)
    print('\t', '\033[1m', 'Route Statistics', '\033[0m')
    print('\t\t', '\033[1m', 'Demand: \033[0m', driver.route.total_quantity, 
          '\033[1m', 'Duration: ', '\033[0m', driver.route.total_duration, 
          '\033[1m', 'Distance: ', '\033[0m', driver.route.total_distance,
          '\033[1m', 'Open: ', '\033[0m', driver.route.is_open)
    location = driver.route.departure
    while location is not None:
        if location.next is None:
            print('\t\t ', location, '(Demand: ', location.demand, ')')
        else:
            print('\t\t ', location, '\n',
                  '\t\t', ' {', '\n'
                  '\t\t\t', ' \"Demand\": ', location.demand, '\n',
                  '\t\t\t', ' \"Distance [previous]\": ', route_manager.location_manager.get_distance(location, location.previous),
                  '\n', '\t\t\t', ' \"Duration [previous]\": ', route_manager.location_manager.get_duration(location, location.previous),
                  '\n', '\t\t', ' }', '\033[1m --> \033[0m', end='\n')
        location = location.next
    print()
# Out:
#  Driver:  Doe,John   Capacity:   20
# 	  Route Statistics
# 		  Demand:  14  Duration:   27.133400000000005  Distance:   24.444000000000003  Open:   False
# 		  5545 Center St, Omaha, NE 68106
#  		  {
# 			  "Demand":  None
#  			  "Distance [previous]":  0.0
#  			  "Duration [previous]":  0.0
#  		  }  -->
# 		  7115 N 50th Ave, Omaha, NE 68152
#  		  {
# 			  "Demand":  5
#  			  "Distance [previous]":  20.061
#  			  "Duration [previous]":  18.5167
#  		  }  -->
# 		  7205 N 73rd Plaza Cir, Omaha, NE 68122
#  		  {
# 			  "Demand":  9
#  			  "Distance [previous]":  4.383
#  			  "Duration [previous]":  8.6167
#  		  }  -->
# 		  5545 Center St, Omaha, NE 68106 (Demand:  None )
#
#  Driver:  Ortega,Alexander   Capacity:   20
# 	  Route Statistics
# 		  Demand:  16  Duration:   20.75  Distance:   11.751999999999999  Open:   False
# 		  5545 Center St, Omaha, NE 68106
#  		  {
# 			  "Demand":  None
#  			  "Distance [previous]":  0.0
#  			  "Duration [previous]":  0.0
#  		  }  -->
# 		  9110 Maplewood Blvd, Omaha, NE 68134
#  		  {
# 			  "Demand":  6
#  			  "Distance [previous]":  11.087
#  			  "Duration [previous]":  17.2333
#  		  }  -->
# 		  8170 Browne St, Omaha, NE 68134
#  		  {
# 			  "Demand":  10
#  			  "Distance [previous]":  3.278
#  			  "Duration [previous]":  5.9667
#  		  }  -->
# 		  5545 Center St, Omaha, NE 68106 (Demand:  None )
#
#  Driver:  Martinez,Rahul   Capacity:   18
# 	  Route Statistics
# 		  Demand:  10  Duration:   18.150000000000002  Distance:   11.519999999999998  Open:   False
# 		  5545 Center St, Omaha, NE 68106
#  		  {
# 			  "Demand":  None
#  			  "Distance [previous]":  0.0
#  			  "Duration [previous]":  0.0
#  		  }  -->
# 		  7350 Graceland Dr, Omaha, NE 68134
#  		  {
# 			  "Demand":  5
#  			  "Distance [previous]":  9.774
#  			  "Duration [previous]":  14.8167
#  		  }  -->
# 		  6795 Emmet St, Omaha, NE 68104
#  		  {
# 			  "Demand":  5
#  			  "Distance [previous]":  1.746
#  			  "Duration [previous]":  3.3333
#  		  }  -->
# 		  5545 Center St, Omaha, NE 68106 (Demand:  None )
#
#  Driver:  Doe,Jane   Capacity:   17
# 	  Route Statistics
# 		  Demand:  16  Duration:   35.599999999999994  Distance:   31.118000000000002  Open:   False
# 		  5545 Center St, Omaha, NE 68106
#  		  {
# 			  "Demand":  None
#  			  "Distance [previous]":  0.0
#  			  "Duration [previous]":  0.0
#  		  }  -->
# 		  9715 Ohern Plz, Omaha, NE 68127
#  		  {
# 			  "Demand":  6
#  			  "Distance [previous]":  8.582
#  			  "Duration [previous]":  12.7167
#  		  }  -->
# 		  9029 Burt St, Omaha, NE 68114
#  		  {
# 			  "Demand":  10
#  			  "Distance [previous]":  11.27
#  			  "Duration [previous]":  13.25
#  		  }  -->
# 		  5545 Center St, Omaha, NE 68106 (Demand:  None )
#
#  Driver:  Cordova,Martin   Capacity:   17
# 	  Route Statistics
# 		  Demand:  5  Duration:   13.1333  Distance:   9.083  Open:   False
# 		  5545 Center St, Omaha, NE 68106
#  		  {
# 			  "Demand":  None
#  			  "Distance [previous]":  0.0
#  			  "Duration [previous]":  0.0
#  		  }  -->
# 		  6705 S 85th St, Omaha, NE 68127
#  		  {
# 			  "Demand":  5
#  			  "Distance [previous]":  9.083
#  			  "Duration [previous]":  13.1333
#  		  }  -->
# 		  5545 Center St, Omaha, NE 68106 (Demand:  None )

# %%
for location in route_manager.locations:
    print(location, location.is_assigned, location.demand)
# Out:
# 9029 Burt St, Omaha, NE 68114 True 10
# 9110 Maplewood Blvd, Omaha, NE 68134 True 6
# 9715 Ohern Plz, Omaha, NE 68127 True 6
# 8170 Browne St, Omaha, NE 68134 True 10
# 6705 S 85th St, Omaha, NE 68127 True 5
# 6795 Emmet St, Omaha, NE 68104 True 5
# 7115 N 50th Ave, Omaha, NE 68152 True 5
# 7205 N 73rd Plaza Cir, Omaha, NE 68122 True 9
# 7350 Graceland Dr, Omaha, NE 68134 True 5

# %%
for driver in route_manager.drivers:
    print(driver, driver.capacity, driver.is_volunteer(), driver.is_full_time(), driver.employee_status)

# %%
all_drivers[0].route.is_open
all_drivers[1].route

# %%
for r in route_manager.savings_manager:
    print(r)

# %%
l3 = Location(address='6001 Dodge Street', city = 'Omaha', state='NE', zipcode=68182)

# %%
route_manager.location_manager.add(l3)

# %%
l3 in all_locations

# %%
all_drivers[0].capacity

# %%
l3.longitude

# %%
l3.created_on

# %%
for driver in route_manager.drivers:
    if driver.get_departure():
        print(driver, driver.get_departure().next)

# %%
Location.nodes.get(address__iexact='6001 dodge Street', city='Omaha', state='NE', zipcode=68182)

# %%
s = set()

# %%
location_manager.get_distance(all_locations[1], all_locations[0])

# %%
location_manager.get_duration(all_locations[0], all_locations[1])

# %%
location_manager.get_duration_savings(all_locations[0], all_locations[1], all_locations[2])

# %%
location_manager.get_distance_savings(all_locations[0], all_locations[1], all_locations[2])

# %%
# !{sys.executable} -m pip install django_neomodel --user
